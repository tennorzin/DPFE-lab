# %%
import numpy as np
import pandas as pd

# %%
data_set=pd.read_csv("billionaire.csv")

# %%
data_set.fillna(value=100)
#to put all the null values as that value we pass
# Out:
#         Unnamed: 0                          name   last_name  age gender  \
# 0              675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 1              676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 2              677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 3              678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 4              679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# ...            ...                           ...         ...  ...    ...
# 352364      358313            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352365      358314            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352366      358315            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352367      358316            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352368      358317            Zygmunt Solorz-Zak  Solorz-Zak   65      M
#
#         time           permanent_country         company  \
# ...

# %%
data_set['age'].fillna(value=35)
#in that column which value is null it will be replaced with the parameter we pass
# Out:
# 0         67
# 1         67
# 2         67
# 3         67
# 4         67
#           ..
# 352364    65
# 352365    65
# 352366    65
# 352367    65
# 352368    65
# Name: age, Length: 352369, dtype: int64

# %% [markdown]
# m=data_set['age'].mean()

# %%
m=data_set['age'].mean()

# %%
m
# Out:
# 72.13032644755924

# %%
r=data_set['age'].mode()

# %%
r
# Out:
# 0    72
# Name: age, dtype: int64

# %%
s=data_set['age'].median()

# %%
s
# Out:
# 72.0

# %%
v=data_set['age'].var()
#for getting variance

# %%
v
# Out:
# 175.24318899150396

# %%
e=data_set['age'].std()
#for getting standard deviation

# %%
e
# Out:
# 13.2379450441337

# %%
data_set.drop(8)
#to drop pariticular row
# Out:
#         Unnamed: 0                          name   last_name  age gender  \
# 0              675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 1              676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 2              677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 3              678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 4              679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# ...            ...                           ...         ...  ...    ...
# 352364      358313            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352365      358314            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352366      358315            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352367      358316            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352368      358317            Zygmunt Solorz-Zak  Solorz-Zak   65      M
#
#         time           permanent_country         company  \
# ...

# %%
#to drop multiple rows list need to passed
data_set.drop([4,5,6])
# Out:
#         Unnamed: 0                          name   last_name  age gender  \
# 0              675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 1              676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 2              677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 3              678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 7              682  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# ...            ...                           ...         ...  ...    ...
# 352364      358313            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352365      358314            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352366      358315            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352367      358316            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352368      358317            Zygmunt Solorz-Zak  Solorz-Zak   65      M
#
#         time           permanent_country         company  \
# ...

# %%
data_set.drop(['gender','company'],axis=1)
#to drop columnssss
# Out:
#         Unnamed: 0                          name   last_name  age  time  \
# 0              675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67  2013
# 1              676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67  2013
# 2              677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67  2013
# 3              678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67  2013
# 4              679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67  2013
# ...            ...                           ...         ...  ...   ...
# 352364      358313            Zygmunt Solorz-Zak  Solorz-Zak   65  2022
# 352365      358314            Zygmunt Solorz-Zak  Solorz-Zak   65  2022
# 352366      358315            Zygmunt Solorz-Zak  Solorz-Zak   65  2022
# 352367      358316            Zygmunt Solorz-Zak  Solorz-Zak   65  2022
# 352368      358317            Zygmunt Solorz-Zak  Solorz-Zak   65  2022
#
#                  permanent_country          main_industry  \
# ...

# %%
data_set['age'].fillna(value=50)
# Out:
# 0         67
# 1         67
# 2         67
# 3         67
# 4         67
#           ..
# 352364    65
# 352365    65
# 352366    65
# 352367    65
# 352368    65
# Name: age, Length: 352369, dtype: int64
